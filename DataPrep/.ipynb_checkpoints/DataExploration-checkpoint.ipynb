# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import load_iris
from pandas.plotting import parallel_coordinates, andrews_curves
from matplotlib import cm as cm

matplotlib.style.use('ggplot')
# %matplotlib inline
#matplotlib notebook

# %% [markdown]
# ## Grouping Data

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                           'foo', 'bar', 'foo', 'foo'],
                   'B' : ['one', 'one', 'two', 'three',
                          'two', 'two', 'one', 'three'],
                   'C' : np.random.randn(8),
                   'D' : np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one -0.690088  0.989798
# 1  bar    one  0.922284 -0.892826
# 2  foo    two  0.228115  0.452091
# 3  bar  three -0.751585  0.197759
# 4  foo    two  0.686358 -0.176539
# 5  bar    two  0.126228  0.311101
# 6  foo    one -0.250152  0.670386
# 7  foo  three  1.643313 -0.671240

# %%
#This is a DataFrameGroupBy object
type(df.groupby('A'))
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
df.groupby('A').count()
# Out:
#      B  C  D
# A
# bar  3  3  3
# foo  5  5  5

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  0.296927 -0.383966
# foo  1.617545  1.264497

# %%
df.groupby('A').mean()
# Out:
#             C         D
# A
# bar  0.098976 -0.127989
# foo  0.323509  0.252899

# %%
df.groupby(['A','B']).mean()
# Out:
#                   C         D
# A   B
# bar one    0.922284 -0.892826
#     three -0.751585  0.197759
#     two    0.126228  0.311101
# foo one   -0.470120  0.830092
#     three  1.643313 -0.671240
#     two    0.457236  0.137776

# %%
# descriptive statistics
df.groupby('A').describe()
# Out:
#         C                                                              \
#     count      mean       std       min       25%       50%       75%
# A
# bar   3.0  0.098976  0.837267 -0.751585 -0.312678  0.126228  0.524256
# foo   5.0  0.323509  0.899876 -0.690088 -0.250152  0.228115  0.686358
#
#                   D                                                    \
#           max count      mean       std       min       25%       50%
# A
# bar  0.922284   3.0 -0.127989  0.664789 -0.892826 -0.347533  0.197759
# foo  1.643313   5.0  0.252899  0.669971 -0.671240 -0.176539  0.452091
#
#
#           75%       max
# A
# bar  0.254430  0.311101
# foo  0.670386  0.989798

# %% [markdown]
# ## Aggregations

# %%
tsdf = pd.DataFrame(np.random.randn(10, 3), columns=['A', 'B', 'C'],
                    index=pd.date_range('1/1/2000', periods=10))
tsdf.iloc[3:7] = np.nan
tsdf
# Out:
#                    A         B         C
# 2000-01-01 -1.885825 -0.801543 -1.427380
# 2000-01-02  1.533285  1.296217 -0.454191
# 2000-01-03  1.665716 -0.313499 -0.563283
# 2000-01-04       NaN       NaN       NaN
# 2000-01-05       NaN       NaN       NaN
# 2000-01-06       NaN       NaN       NaN
# 2000-01-07       NaN       NaN       NaN
# 2000-01-08 -2.410507 -0.446985 -1.599439
# 2000-01-09 -0.272789  0.706029  0.635431
# 2000-01-10 -0.626935  0.539751  0.311727

# %%
#you can also create custom describe functions with agg() and functools module
tsdf.agg(['sum', lambda x: x.mean()])
# Out:
#                  A         B         C
# sum      -1.997055  0.979971 -3.097135
# <lambda> -0.332843  0.163328 -0.516189

# %% [markdown]
# ## Pivot Tables

# %%
df2 = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
                    'B' : ['A', 'B', 'C'] * 4,
                    'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                    'D' : np.random.randn(12),
                    'E' : np.random.randn(12)})
df2
# Out:
#         A  B    C         D         E
# 0     one  A  foo  1.098690  1.232580
# 1     one  B  foo  0.890735  0.086283
# 2     two  C  foo -0.902212  0.167755
# 3   three  A  bar -1.727630 -1.339652
# 4     one  B  bar  0.475475 -0.019789
# 5     one  C  bar -0.752979 -0.530946
# 6     two  A  foo  0.741346  0.352535
# 7   three  B  foo -0.859046 -0.108878
# 8     one  C  foo  0.245922 -0.139767
# 9     one  A  bar  0.452921 -1.483031
# 10    two  B  bar -1.631435 -0.520326
# 11  three  C  bar -0.071803 -0.166103

# %%
pd.pivot_table(df2, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A  0.452921  1.098690
#       B  0.475475  0.890735
#       C -0.752979  0.245922
# three A -1.727630       NaN
#       B       NaN -0.859046
#       C -0.071803       NaN
# two   A       NaN  0.741346
#       B -1.631435       NaN
#       C       NaN -0.902212

# %%
pd.pivot_table(df2, values='D', index=['A', 'B'], columns=['C'], aggfunc=np.sum)
# Out:
# C             bar       foo
# A     B
# one   A  0.452921  1.098690
#       B  0.475475  0.890735
#       C -0.752979  0.245922
# three A -1.727630       NaN
#       B       NaN -0.859046
#       C -0.071803       NaN
# two   A       NaN  0.741346
#       B -1.631435       NaN
#       C       NaN -0.902212

# %% [markdown]
# ## Time Series

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample('5Min').sum()
# Out:
# 2012-01-01    26581
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')
ts = pd.Series(np.random.randn(len(rng)), rng)
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.877893
# 2012-03-07 00:00:00+00:00   -0.210593
# 2012-03-08 00:00:00+00:00   -0.564725
# 2012-03-09 00:00:00+00:00    0.860652
# 2012-03-10 00:00:00+00:00    0.532183
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00   -0.877893
# 2012-03-06 19:00:00-05:00   -0.210593
# 2012-03-07 19:00:00-05:00   -0.564725
# 2012-03-08 19:00:00-05:00    0.860652
# 2012-03-09 19:00:00-05:00    0.532183
# Freq: D, dtype: float64

# %% [markdown]
# ## Descriptive statistics

# %%
#create df from dicts
df3 = pd.DataFrame({ 'A' : 1.,
                    'B' : pd.Timestamp('20130102'),
                    'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                    'D' : np.array([3] * 4,dtype='int32'),
                    'E' : pd.Categorical(["test","train","test","train"]),
                    'F' : 'foo' })
df3
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
#create DF from Random data
df4 = pd.DataFrame(np.random.randn(10,4))
df4
# Out:
#           0         1         2         3
# 0 -1.103138  0.294002  0.466532  1.172952
# 1  0.362669  1.145972 -0.403248 -0.185799
# 2 -0.685856  1.399025  0.320138  0.431660
# 3 -0.560250 -0.166267 -1.953828 -0.623511
# 4  0.820088 -1.588946 -0.481010 -0.597651
# 5 -1.081881  0.058809  0.429397 -0.504479
# 6  0.971503  0.727088  1.244826 -0.830293
# 7 -0.274040  0.242628  0.106241 -0.043552
# 8  0.331106 -1.245831 -1.426940  0.916015
# 9 -1.053403  0.099296  0.618633 -0.126317

# %%
df4.describe()
# Out:
#                0          1          2          3
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.227320   0.096578  -0.107926  -0.039098
# std     0.795626   0.940982   0.976343   0.677262
# min    -1.103138  -1.588946  -1.953828  -0.830293
# 25%    -0.961517  -0.109998  -0.461569  -0.574358
# 50%    -0.417145   0.170962   0.213189  -0.156058
# 75%     0.354779   0.618817   0.457248   0.312857
# max     0.971503   1.399025   1.244826   1.172952

# %%
df4.mean()
# Out:
# 0   -0.227320
# 1    0.096578
# 2   -0.107926
# 3   -0.039098
# dtype: float64

# %%
#kurtosis
df4.kurtosis()
# Out:
# 0   -1.544474
# 1   -0.003856
# 2    0.108823
# 3   -0.508561
# dtype: float64

# %%
#skew
df4.skew()
# Out:
# 0    0.347048
# 1   -0.599996
# 2   -0.801401
# 3    0.796916
# dtype: float64

# %% [markdown]
# ### Descriptive stats using apply

# %%
df4.apply(np.sum)
# Out:
# 0   -2.273202
# 1    0.965776
# 2   -1.079260
# 3   -0.390977
# dtype: float64

# %%
df4.apply(lambda x: x.max() - x.min())
# Out:
# 0    2.074641
# 1    2.987971
# 2    3.198653
# 3    2.003245
# dtype: float64

# %% [markdown]
# ## Histograms / Frequency tables

# %%
#Series value count
df4.iloc[:,0].value_counts()
# Out:
# -1.081881    1
# -1.103138    1
# -0.560250    1
#  0.362669    1
# -0.685856    1
#  0.331106    1
#  0.820088    1
# -0.274040    1
#  0.971503    1
# -1.053403    1
# Name: 0, dtype: int64

# %% [markdown]
# ### Discretizing  or categorizing continuous data

# %%
arr = np.random.randn(20)
factor = pd.cut(arr, 4)
factor.value_counts()
# Out:
# (-2.206, -1.253]    3
# (-1.253, -0.303]    3
# (-0.303, 0.646]     6
# (0.646, 1.596]      8
# dtype: int64

# %%
factor = pd.cut(arr, [-5, -1, 0, 1, 5])
factor.value_counts()
# Out:
# (-5, -1]    3
# (-1, 0]     5
# (0, 1]      7
# (1, 5]      5
# dtype: int64

# %%
#relative frequencies or normalizing

# %% [markdown]
# ## Compute Quantiles

# %%
arr = np.random.randn(30)
factor = pd.qcut(arr, [0, .25, .5, .75, 1])
pd.value_counts(factor)
# Out:
# (0.564, 1.893]      8
# (-2.639, -0.587]    8
# (0.0973, 0.564]     7
# (-0.587, 0.0973]    7
# dtype: int64

# %% [markdown]
# ## Plotting

# %%
#plot timeseries
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
#plot dataframe
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                  columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure(); df.plot(); plt.legend(loc='best')

# %%
#create DF from Random data
df5 = pd.DataFrame(np.random.randn(10,4),columns=['F1','F2','F3','Label'])
df5.F1 = pd.Series(['one','one','one','two','two','two','three','three','three','Pi'])
df5
# Out:
#       F1        F2        F3     Label
# 0    one  1.284457 -0.493492 -0.175976
# 1    one  1.309035  1.223800 -0.536071
# 2    one -0.895614 -1.134639 -1.148396
# 3    two -1.196751 -0.789966  0.455524
# 4    two -0.964387  0.110379  0.005877
# 5    two  0.173862  2.296211 -1.011865
# 6  three -0.046297  0.088410 -0.337124
# 7  three  1.754252 -1.057773 -1.087820
# 8  three -1.009278  1.179802 -0.771848
# 9     Pi  1.428341 -1.951119 -1.480547

# %%
df5.plot.bar()

# %%
df5.plot.barh()

# %%
df5.plot.bar(stacked=True)

# %%
#conditional barplot???

# %%
df5.F1.value_counts().plot.bar()

# %%
df5.plot.hist(bins=5, alpha=0.5, stacked=True, orientation='vertical', cumulative=True)

# %%
df5.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a27299b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27836198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a27637240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a278a3c18>]], dtype=object)

# %%
#conditional histogram???

# %%
df5.plot.box()

# %%
plt.figure()
df5.boxplot(by='F1', vert=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a27617c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2765bda0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a274444e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a273b9da0>]], dtype=object)

# %%
df6 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df6.plot.area();

# %%
df7 = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df7.plot.scatter(x='a', y='b', title='scatter', marker='^', c='blue', s=20);

# %%
df8 = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])

df8['b'] = df8['b'] + np.arange(1000)

df8.plot.hexbin(x='a', y='b', gridsize=25)

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a27f4b048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a280b9240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27febb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28175eb8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a281dc160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a281dc198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a282b7908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a282f2da0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a28386438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a283963c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28454438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a284a4be0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2851d438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a285817b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a285fb550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a28659f60>]], dtype=object)

# %%
df.plot(subplots=True, figsize=(6, 6));

# %%
#parallel coordinates to view multiple dimensions in one graph
#do not plot more than 10 features
#make sure the features are in the same scale
data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names) 

df['target_names'] = [data.target_names[i] for i in data.target]

# Parallel Coordinates Start Here:
parallel_coordinates(df, 'target_names')

# %%
#Plotting andrew's curves
#use it only with numeric values
andrews_curves(df, 'target_names')

# %% [markdown]
# ## Plotting Images

# %%
rand_img = np.random.randint(low=-10,high=10,size=(10,10))
rand_img.shape
# Out:
# (10, 10)

# %%
plt.imshow(rand_img)

# %%
rand_img2 = np.random.randint(low=0,high=255,size=(100,100,3),dtype='uint8')
rand_img2.shape
rand_img2.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(rand_img2)

# %%
#show correlation matrix using imshow
cmap = cm.get_cmap('jet', 30)
plt.imshow(df.corr(), cmap=plt.cm.coolwarm, interpolation='nearest')

# %% [markdown]
# ## 3D Plots

# %%
data = load_iris()
data.feature_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
df = pd.DataFrame(data.data, columns=data.feature_names)

# %%
fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
ax.set_zlabel('petal_length')

ax.scatter(df.sepal_length, df.sepal_width, df.petal_length, c='r', marker='.')
plt.show()
