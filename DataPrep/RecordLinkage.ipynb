# %% [markdown]
# # Record Linkage Template
# - Clean
# - Index
# - Compare
# - Classify
# - Evaluate

# %%
import numpy as np
import pandas as pd
import recordlinkage
import math
from recordlinkage.datasets import load_febrl4

# %% [markdown]
# ## Data Understanding and Cleaning
# - make data consistent
# - use same column names

# %%
dfA, dfB = load_febrl4()

# %%
dfA.shape
# Out:
# (5000, 10)

# %%
dfA.head()
# Out:
#              given_name   surname street_number            address_1  \
# rec_id
# rec-1070-org   michaela   neumann             8       stanley street
# rec-1016-org   courtney   painter            12    pinkerton circuit
# rec-4405-org    charles     green            38  salkauskas crescent
# rec-1288-org    vanessa      parr           905       macquoid place
# rec-3585-org    mikayla  malloney            37        randwick road
#
#                       address_2            suburb postcode state  \
# rec_id
# rec-1070-org              miami     winston hills     4223   nsw
# rec-1016-org         bega flats         richlands     4560   vic
# rec-4405-org               kela             dapto     4566   nsw
# rec-1288-org  broadbridge manor     south grafton     2135    sa
# rec-3585-org            avalind  hoppers crossing     4552   vic
#
#              date_of_birth soc_sec_id
# rec_id
# rec-1070-org      19151111    5304218
# rec-1016-org      19161214    4066625
# rec-4405-org      19480930    4365168
# rec-1288-org      19951119    9239102
# rec-3585-org      19860208    7207688

# %%
dfA.dtypes
# Out:
# given_name       object
# surname          object
# street_number    object
# address_1        object
# address_2        object
# suburb           object
# postcode         object
# state            object
# date_of_birth    object
# soc_sec_id       object
# dtype: object

# %%
dfA.describe()
# Out:
#        given_name surname street_number      address_1   address_2     suburb  \
# count        4888    4952          4842           4902        4580       4945
# unique        770    1827           450           2399        2575       1634
# top        emiily   white             1  forbes street  rowethorpe  toowoomba
# freq           85     151           161             18          52         40
#
#        postcode state date_of_birth soc_sec_id
# count      5000  4950          4906       5000
# unique     1419     8          4588       5000
# top        4740   nsw      19950105    3742016
# freq         30  1686             3          1

# %%
dfB.shape
# Out:
# (5000, 10)

# %%
dfB.head()
# Out:
#                given_name    surname street_number             address_1  \
# rec_id
# rec-561-dup-0       elton        NaN             3         light setreet
# rec-2642-dup-0   mitchell      maxon            47         edkins street
# rec-608-dup-0         NaN      white            72       lambrigg street
# rec-3239-dup-0      elk i    menzies             1          lyster place
# rec-2886-dup-0        NaN  garanggar           NaN  may maxwell crescent
#
#                          address_2             suburb postcode state  \
# rec_id
# rec-561-dup-0             pinehill         windermere     3212   vic
# rec-2642-dup-0           lochaoair         north ryde     3355   nsw
# rec-608-dup-0             kelgoola  broadbeach waters     3159   vic
# rec-3239-dup-0                 NaN          northwood     2585   vic
# rec-2886-dup-0  springettst arcade        forest hill     2342   vic
#
#                date_of_birth soc_sec_id
# rec_id
# rec-561-dup-0       19651013    1551941
# rec-2642-dup-0      19390212    8859999
# rec-608-dup-0       19620216    9731855
# rec-3239-dup-0      19980624    4970481
# rec-2886-dup-0      19921016    1366884

# %%
dfB.dtypes
# Out:
# given_name       object
# surname          object
# street_number    object
# address_1        object
# address_2        object
# suburb           object
# postcode         object
# state            object
# date_of_birth    object
# soc_sec_id       object
# dtype: object

# %%
dfB.describe()
# Out:
#        given_name surname street_number        address_1       address_2  \
# count        4766    4898          4713             4780            4149
# unique       1702    2633           453             3516            3306
# top        emiily   white             1  badimara street  brentwood vlge
# freq           68     105           171               12              33
#
#            suburb postcode state date_of_birth soc_sec_id
# count        4894     5000  4893          4801       5000
# unique       2403     1691    50          4505       5000
# top     toowoomba     4740   nsw      19900531    3742016
# freq           34       23  1637             3          1

# %% [markdown]
# ## Indexing

# %% [markdown]
# ### Full Indexing

# %%
indexer = recordlinkage.FullIndex()
pairs = indexer.index(dfA, dfB)
# Out:
# WARNING:recordlinkage:The number of record pairs is large. Consider a different indexation algorithm for better performance.

# %%
print (len(dfA), len(dfB), len(pairs))
# Out:
# 5000 5000 25000000

# %% [markdown]
# ### Blocking

# %%
indexer = recordlinkage.BlockIndex(on='given_name')
pairs = indexer.index(dfA, dfB)

print (len(pairs))
# Out:
# 77249

# %% [markdown]
# ### Sorted Neighbourhood Indexing

# %% [markdown]
# ## Comparing

# %%
# This cell can take some time to compute.
compare_cl = recordlinkage.Compare()

compare_cl.exact('given_name', 'given_name', label='given_name')
compare_cl.string('surname', 'surname', method='jarowinkler', threshold=0.85, label='surname')
compare_cl.exact('date_of_birth', 'date_of_birth', label='date_of_birth')
compare_cl.exact('suburb', 'suburb', label='suburb')
compare_cl.exact('state', 'state', label='state')
compare_cl.string('address_1', 'address_1', threshold=0.85, label='address_1')

features = compare_cl.compute(pairs, dfA, dfB)

# %%
features.head()
# Out:
#                              given_name  surname  date_of_birth  suburb  \
# rec_id       rec_id
# rec-1070-org rec-3024-dup-0           1      0.0              0       0
#              rec-2371-dup-0           1      0.0              0       0
#              rec-4652-dup-0           1      0.0              0       0
#              rec-4795-dup-0           1      0.0              0       0
#              rec-1314-dup-0           1      0.0              0       0
#
#                              state  address_1
# rec_id       rec_id
# rec-1070-org rec-3024-dup-0      1        0.0
#              rec-2371-dup-0      0        0.0
#              rec-4652-dup-0      0        0.0
#              rec-4795-dup-0      1        0.0
#              rec-1314-dup-0      1        0.0

# %%
features.describe()
# Out:
#        given_name       surname  date_of_birth        suburb         state  \
# count     77249.0  77249.000000   77249.000000  77249.000000  77249.000000
# mean          1.0      0.044428       0.037929      0.032259      0.248767
# std           0.0      0.206045       0.191027      0.176689      0.432301
# min           1.0      0.000000       0.000000      0.000000      0.000000
# 25%           1.0      0.000000       0.000000      0.000000      0.000000
# 50%           1.0      0.000000       0.000000      0.000000      0.000000
# 75%           1.0      0.000000       0.000000      0.000000      0.000000
# max           1.0      1.000000       1.000000      1.000000      1.000000
#
#           address_1
# count  77249.000000
# mean       0.036700
# std        0.188024
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
# Sum the comparison results.
match_grps = features.sum(axis=1).value_counts().sort_index(ascending=False)
match_grps
# Out:
# 6.0     1566
# 5.0     1332
# 4.0      343
# 3.0      146
# 2.0    16427
# 1.0    57435
# dtype: int64

# %%
features[features.sum(axis=1) > 3]
# Out:
#                              given_name  surname  date_of_birth  suburb  \
# rec_id       rec_id
# rec-2371-org rec-2371-dup-0           1      1.0              1       1
# rec-3024-org rec-3024-dup-0           1      1.0              1       0
# rec-4652-org rec-4652-dup-0           1      1.0              1       0
# rec-4795-org rec-4795-dup-0           1      1.0              1       1
# rec-1016-org rec-1016-dup-0           1      1.0              1       1
# rec-2463-org rec-2463-dup-0           1      1.0              0       1
# rec-521-org  rec-521-dup-0            1      1.0              1       1
# rec-786-org  rec-786-dup-0            1      1.0              1       1
# rec-572-org  rec-572-dup-0            1      0.0              0       1
# rec-2389-org rec-2389-dup-0           1      1.0              1       1
# rec-1209-org rec-1209-dup-0           1      1.0              1       1
# rec-4141-org rec-4141-dup-0           1      1.0              1       1
# rec-4405-org rec-4405-dup-0           1      1.0              1       1
# rec-738-org  rec-738-dup-0            1      1.0              1       0
# rec-3150-org rec-3150-dup-0           1      1.0              1       1
# rec-4914-org rec-4914-dup-0           1      1.0              1       0
# rec-4782-org rec-4782-dup-0           1      1.0              1       1
# rec-1236-org rec-1236-dup-0           1      1.0              1       1
# rec-2150-org rec-2150-dup-0           1      1.0              1       1
# rec-1288-org rec-1288-dup-0           1      1.0              1       0
# rec-2811-org rec-2811-dup-0           1      1.0              0       1
# rec-4787-org rec-4787-dup-0           1      1.0              1       1
# rec-3585-org rec-3585-dup-0           1      1.0              1       1
# rec-2942-org rec-2942-dup-0           1      1.0              1       1
# rec-3292-org rec-3292-dup-0           1      1.0              1       1
# rec-298-org  rec-298-dup-0            1      1.0              1       1
# rec-28-org   rec-28-dup-0             1      1.0              1       1
# rec-3460-org rec-3460-dup-0           1      1.0              1       1
# rec-3348-org rec-3348-dup-0           1      1.0              1       1
# rec-4337-org rec-4337-dup-0           1      1.0              1       1
# ...                                 ...      ...            ...     ...
# rec-1492-org rec-1492-dup-0           1      1.0              1       1
# rec-4519-org rec-4519-dup-0           1      1.0              1       1
# rec-1468-org rec-1468-dup-0           1      1.0              1       1
# rec-3283-org rec-3283-dup-0           1      1.0              0       0
# rec-1245-org rec-1245-dup-0           1      1.0              1       1
# rec-1502-org rec-1502-dup-0           1      1.0              1       1
# rec-3227-org rec-3227-dup-0           1      1.0              1       0
# rec-4004-org rec-4004-dup-0           1      1.0              1       1
# rec-3087-org rec-3087-dup-0           1      1.0              1       1
# rec-991-org  rec-991-dup-0            1      1.0              1       1
# rec-2820-org rec-2820-dup-0           1      1.0              1       1
# rec-1984-org rec-1984-dup-0           1      1.0              1       1
# rec-1920-org rec-1920-dup-0           1      1.0              1       1
# rec-303-org  rec-303-dup-0            1      1.0              1       1
# rec-1915-org rec-1915-dup-0           1      1.0              1       1
# rec-4739-org rec-4739-dup-0           1      1.0              1       0
# rec-4603-org rec-4603-dup-0           1      1.0              1       1
# rec-3711-org rec-3711-dup-0           1      1.0              1       1
# rec-4912-org rec-4912-dup-0           1      1.0              1       1
# rec-664-org  rec-664-dup-0            1      1.0              1       1
# rec-4031-org rec-4031-dup-0           1      1.0              1       1
# rec-1413-org rec-1413-dup-0           1      1.0              1       1
# rec-735-org  rec-735-dup-0            1      1.0              0       1
# rec-1361-org rec-1361-dup-0           1      1.0              1       1
# rec-2571-org rec-2571-dup-0           1      1.0              0       1
# rec-4528-org rec-4528-dup-0           1      1.0              1       1
# rec-4887-org rec-4887-dup-0           1      1.0              1       0
# rec-4350-org rec-4350-dup-0           1      1.0              1       1
# rec-4569-org rec-4569-dup-0           1      1.0              1       1
# rec-3125-org rec-3125-dup-0           1      1.0              1       0
#
#                              state  address_1
# rec_id       rec_id
# rec-2371-org rec-2371-dup-0      1        1.0
# rec-3024-org rec-3024-dup-0      1        0.0
# rec-4652-org rec-4652-dup-0      1        1.0
# rec-4795-org rec-4795-dup-0      1        1.0
# rec-1016-org rec-1016-dup-0      0        1.0
# rec-2463-org rec-2463-dup-0      1        1.0
# rec-521-org  rec-521-dup-0       1        1.0
# rec-786-org  rec-786-dup-0       1        1.0
# rec-572-org  rec-572-dup-0       1        1.0
# rec-2389-org rec-2389-dup-0      1        1.0
# rec-1209-org rec-1209-dup-0      1        0.0
# rec-4141-org rec-4141-dup-0      0        1.0
# rec-4405-org rec-4405-dup-0      1        1.0
# rec-738-org  rec-738-dup-0       0        1.0
# rec-3150-org rec-3150-dup-0      1        1.0
# rec-4914-org rec-4914-dup-0      1        1.0
# rec-4782-org rec-4782-dup-0      1        1.0
# rec-1236-org rec-1236-dup-0      1        1.0
# rec-2150-org rec-2150-dup-0      1        1.0
# rec-1288-org rec-1288-dup-0      1        1.0
# rec-2811-org rec-2811-dup-0      1        1.0
# rec-4787-org rec-4787-dup-0      1        1.0
# rec-3585-org rec-3585-dup-0      1        1.0
# rec-2942-org rec-2942-dup-0      1        1.0
# rec-3292-org rec-3292-dup-0      1        1.0
# rec-298-org  rec-298-dup-0       1        0.0
# rec-28-org   rec-28-dup-0        1        1.0
# rec-3460-org rec-3460-dup-0      1        0.0
# rec-3348-org rec-3348-dup-0      1        1.0
# rec-4337-org rec-4337-dup-0      1        1.0
# ...                            ...        ...
# rec-1492-org rec-1492-dup-0      1        1.0
# rec-4519-org rec-4519-dup-0      1        1.0
# rec-1468-org rec-1468-dup-0      1        1.0
# rec-3283-org rec-3283-dup-0      1        1.0
# rec-1245-org rec-1245-dup-0      1        1.0
# rec-1502-org rec-1502-dup-0      1        1.0
# rec-3227-org rec-3227-dup-0      1        1.0
# rec-4004-org rec-4004-dup-0      1        0.0
# rec-3087-org rec-3087-dup-0      1        1.0
# rec-991-org  rec-991-dup-0       1        1.0
# rec-2820-org rec-2820-dup-0      1        1.0
# rec-1984-org rec-1984-dup-0      1        1.0
# rec-1920-org rec-1920-dup-0      1        1.0
# rec-303-org  rec-303-dup-0       1        1.0
# rec-1915-org rec-1915-dup-0      1        1.0
# rec-4739-org rec-4739-dup-0      1        1.0
# rec-4603-org rec-4603-dup-0      1        1.0
# rec-3711-org rec-3711-dup-0      0        1.0
# rec-4912-org rec-4912-dup-0      1        1.0
# rec-664-org  rec-664-dup-0       1        1.0
# rec-4031-org rec-4031-dup-0      1        1.0
# rec-1413-org rec-1413-dup-0      1        1.0
# rec-735-org  rec-735-dup-0       1        1.0
# rec-1361-org rec-1361-dup-0      1        1.0
# rec-2571-org rec-2571-dup-0      1        0.0
# rec-4528-org rec-4528-dup-0      1        1.0
# rec-4887-org rec-4887-dup-0      1        1.0
# rec-4350-org rec-4350-dup-0      1        1.0
# rec-4569-org rec-4569-dup-0      1        0.0
# rec-3125-org rec-3125-dup-0      1        1.0
#
# [3241 rows x 6 columns]

# %% [markdown]
# ### Sampling

# %%
#Calculating sample size
p = 0.5
q = 0.5
z = 1.96
err = 0.1
sample_size = (p * q * (z**2)) / (err**2)
sample_size
# Out:
# 96.03999999999998

# %%
#calculating proportions
sample_size = 100
match_prps = (match_grps / len(pairs)) * sample_size
match_prps
# Out:
# 6.0     2.027211
# 5.0     1.724294
# 4.0     0.444019
# 3.0     0.188999
# 2.0    21.265000
# 1.0    74.350477
# dtype: float64

# %%
def strat_sampling(data_df, match_prps):
    match_sum_grp = data_df.loc[:,'match_sum'].unique()[0]
    return data_df.sample(max(1, int(round(match_prps.loc[match_sum_grp]))))

# %%
features.loc[:,'match_sum'] = features.sum(axis=1)
features.head()
# Out:
#                              given_name  surname  date_of_birth  suburb  \
# rec_id       rec_id
# rec-1070-org rec-3024-dup-0           1      0.0              0       0
#              rec-2371-dup-0           1      0.0              0       0
#              rec-4652-dup-0           1      0.0              0       0
#              rec-4795-dup-0           1      0.0              0       0
#              rec-1314-dup-0           1      0.0              0       0
#
#                              state  address_1  match_sum
# rec_id       rec_id
# rec-1070-org rec-3024-dup-0      1        0.0        2.0
#              rec-2371-dup-0      0        0.0        1.0
#              rec-4652-dup-0      0        0.0        1.0
#              rec-4795-dup-0      1        0.0        2.0
#              rec-1314-dup-0      1        0.0        2.0

# %%
strat_sample_feat = features.groupby('match_sum', group_keys=False).apply(lambda x: strat_sampling(x, match_prps))
strat_sample_feat
# Out:
#                              given_name  surname  date_of_birth  suburb  \
# rec_id       rec_id
# rec-3034-org rec-996-dup-0            1      0.0              0       0
# rec-4040-org rec-4171-dup-0           1      0.0              0       0
# rec-2036-org rec-3250-dup-0           1      0.0              0       0
# rec-3591-org rec-134-dup-0            1      0.0              0       0
# rec-45-org   rec-2812-dup-0           1      0.0              0       0
# rec-3299-org rec-3722-dup-0           1      0.0              0       0
# rec-337-org  rec-3247-dup-0           1      0.0              0       0
# rec-4312-org rec-2972-dup-0           1      0.0              0       0
# rec-714-org  rec-4023-dup-0           1      0.0              0       0
# rec-2559-org rec-4353-dup-0           1      0.0              0       0
# rec-2490-org rec-2351-dup-0           1      0.0              0       0
# rec-4209-org rec-4584-dup-0           1      0.0              0       0
# rec-4703-org rec-1911-dup-0           1      0.0              0       0
# rec-3675-org rec-505-dup-0            1      0.0              0       0
# rec-3433-org rec-4950-dup-0           1      0.0              0       0
# rec-2973-org rec-1726-dup-0           1      0.0              0       0
# rec-3921-org rec-1942-dup-0           1      0.0              0       0
# rec-2808-org rec-2249-dup-0           1      0.0              0       0
# rec-4522-org rec-2446-dup-0           1      0.0              0       0
# rec-2574-org rec-3207-dup-0           1      0.0              0       0
# rec-2588-org rec-1580-dup-0           1      0.0              0       0
# rec-3695-org rec-3130-dup-0           1      0.0              0       0
# rec-629-org  rec-1998-dup-0           1      0.0              0       0
# rec-93-org   rec-777-dup-0            1      0.0              0       0
# rec-4657-org rec-4616-dup-0           1      0.0              0       0
# rec-2302-org rec-722-dup-0            1      0.0              0       0
# rec-3366-org rec-1982-dup-0           1      0.0              0       0
# rec-4623-org rec-1215-dup-0           1      0.0              0       0
# rec-3044-org rec-117-dup-0            1      0.0              0       0
# rec-112-org  rec-2215-dup-0           1      0.0              0       0
# ...                                 ...      ...            ...     ...
# rec-4431-org rec-2259-dup-0           1      0.0              0       0
# rec-207-org  rec-4083-dup-0           1      0.0              0       0
# rec-1080-org rec-3488-dup-0           1      0.0              0       0
# rec-4225-org rec-4288-dup-0           1      0.0              0       0
# rec-1549-org rec-4472-dup-0           1      0.0              0       0
# rec-1455-org rec-1908-dup-0           1      0.0              0       1
# rec-243-org  rec-2012-dup-0           1      0.0              0       0
# rec-3216-org rec-4950-dup-0           1      0.0              0       0
# rec-2681-org rec-1746-dup-0           1      0.0              0       0
# rec-1045-org rec-3245-dup-0           1      0.0              0       0
# rec-827-org  rec-2442-dup-0           1      0.0              0       0
# rec-3963-org rec-3317-dup-0           1      0.0              0       0
# rec-2629-org rec-1713-dup-0           1      0.0              0       0
# rec-760-org  rec-1136-dup-0           1      0.0              0       0
# rec-4507-org rec-3709-dup-0           1      0.0              0       0
# rec-4551-org rec-1142-dup-0           1      0.0              0       0
# rec-465-org  rec-741-dup-0            1      0.0              0       0
# rec-1980-org rec-2457-dup-0           1      0.0              0       0
# rec-3582-org rec-3024-dup-0           1      0.0              0       0
# rec-4526-org rec-3260-dup-0           1      0.0              0       0
# rec-1978-org rec-400-dup-0            1      0.0              0       0
# rec-4181-org rec-2284-dup-0           1      0.0              0       0
# rec-615-org  rec-4353-dup-0           1      0.0              0       0
# rec-2573-org rec-4086-dup-0           1      0.0              0       0
# rec-921-org  rec-1127-dup-0           1      0.0              0       0
# rec-3123-org rec-3123-dup-0           1      1.0              0       0
# rec-167-org  rec-167-dup-0            1      1.0              1       0
# rec-980-org  rec-980-dup-0            1      1.0              1       1
# rec-4275-org rec-4275-dup-0           1      1.0              1       1
# rec-38-org   rec-38-dup-0             1      1.0              1       1
#
#                              state  address_1  match_sum
# rec_id       rec_id
# rec-3034-org rec-996-dup-0       0        0.0        1.0
# rec-4040-org rec-4171-dup-0      0        0.0        1.0
# rec-2036-org rec-3250-dup-0      0        0.0        1.0
# rec-3591-org rec-134-dup-0       0        0.0        1.0
# rec-45-org   rec-2812-dup-0      0        0.0        1.0
# rec-3299-org rec-3722-dup-0      0        0.0        1.0
# rec-337-org  rec-3247-dup-0      0        0.0        1.0
# rec-4312-org rec-2972-dup-0      0        0.0        1.0
# rec-714-org  rec-4023-dup-0      0        0.0        1.0
# rec-2559-org rec-4353-dup-0      0        0.0        1.0
# rec-2490-org rec-2351-dup-0      0        0.0        1.0
# rec-4209-org rec-4584-dup-0      0        0.0        1.0
# rec-4703-org rec-1911-dup-0      0        0.0        1.0
# rec-3675-org rec-505-dup-0       0        0.0        1.0
# rec-3433-org rec-4950-dup-0      0        0.0        1.0
# rec-2973-org rec-1726-dup-0      0        0.0        1.0
# rec-3921-org rec-1942-dup-0      0        0.0        1.0
# rec-2808-org rec-2249-dup-0      0        0.0        1.0
# rec-4522-org rec-2446-dup-0      0        0.0        1.0
# rec-2574-org rec-3207-dup-0      0        0.0        1.0
# rec-2588-org rec-1580-dup-0      0        0.0        1.0
# rec-3695-org rec-3130-dup-0      0        0.0        1.0
# rec-629-org  rec-1998-dup-0      0        0.0        1.0
# rec-93-org   rec-777-dup-0       0        0.0        1.0
# rec-4657-org rec-4616-dup-0      0        0.0        1.0
# rec-2302-org rec-722-dup-0       0        0.0        1.0
# rec-3366-org rec-1982-dup-0      0        0.0        1.0
# rec-4623-org rec-1215-dup-0      0        0.0        1.0
# rec-3044-org rec-117-dup-0       0        0.0        1.0
# rec-112-org  rec-2215-dup-0      0        0.0        1.0
# ...                            ...        ...        ...
# rec-4431-org rec-2259-dup-0      0        0.0        1.0
# rec-207-org  rec-4083-dup-0      0        0.0        1.0
# rec-1080-org rec-3488-dup-0      0        0.0        1.0
# rec-4225-org rec-4288-dup-0      1        0.0        2.0
# rec-1549-org rec-4472-dup-0      1        0.0        2.0
# rec-1455-org rec-1908-dup-0      0        0.0        2.0
# rec-243-org  rec-2012-dup-0      1        0.0        2.0
# rec-3216-org rec-4950-dup-0      1        0.0        2.0
# rec-2681-org rec-1746-dup-0      1        0.0        2.0
# rec-1045-org rec-3245-dup-0      1        0.0        2.0
# rec-827-org  rec-2442-dup-0      1        0.0        2.0
# rec-3963-org rec-3317-dup-0      1        0.0        2.0
# rec-2629-org rec-1713-dup-0      1        0.0        2.0
# rec-760-org  rec-1136-dup-0      1        0.0        2.0
# rec-4507-org rec-3709-dup-0      1        0.0        2.0
# rec-4551-org rec-1142-dup-0      1        0.0        2.0
# rec-465-org  rec-741-dup-0       1        0.0        2.0
# rec-1980-org rec-2457-dup-0      1        0.0        2.0
# rec-3582-org rec-3024-dup-0      1        0.0        2.0
# rec-4526-org rec-3260-dup-0      1        0.0        2.0
# rec-1978-org rec-400-dup-0       1        0.0        2.0
# rec-4181-org rec-2284-dup-0      1        0.0        2.0
# rec-615-org  rec-4353-dup-0      1        0.0        2.0
# rec-2573-org rec-4086-dup-0      1        0.0        2.0
# rec-921-org  rec-1127-dup-0      1        1.0        3.0
# rec-3123-org rec-3123-dup-0      1        1.0        4.0
# rec-167-org  rec-167-dup-0       1        1.0        5.0
# rec-980-org  rec-980-dup-0       1        0.0        5.0
# rec-4275-org rec-4275-dup-0      1        1.0        6.0
# rec-38-org   rec-38-dup-0        1        1.0        6.0
#
# [101 rows x 7 columns]

# %%
strat_sample_feat.loc[:,'match_sum'].value_counts().sort_index(ascending=False)
# Out:
# 6.0     2
# 5.0     2
# 4.0     1
# 3.0     1
# 2.0    21
# 1.0    74
# Name: match_sum, dtype: int64

# %% [markdown]
# ## Classify

# %% [markdown]
# ## Evaluate
