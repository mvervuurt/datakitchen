# %%
import pandas as pd
from pandas import Series
from matplotlib import pyplot as plt

# %%
series = pd.read_csv('daily-total-female-births-in-cal.csv', sep=';', header=0)
series.plot()
pyplot.show()

# %%
series = pd.read_csv('international-airline-passengers.csv', sep=';', header=0)
series.plot()
pyplot.show()
